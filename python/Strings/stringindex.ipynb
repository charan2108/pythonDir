# %%
d = "Aerospace - Engineering"
print(d)
print(type(d))
print(len(d))
print("print d[0] is",d[0])
print("print d[1] is",d[1])
print("print d[2] is",d[2])
print("print d[3] is",d[3])
print("print d[4] is",d[4])
print("print d[5] is",d[5])
print("print d[6] is",d[6])
print("print d[7] is",d[7])
print("print d[8] is",d[8])
# print("print d[9] is",d[9])
print("print d[10] is",d[10])
# print("print d[11] is",d[11])
print("print d[12] is",d[12])
print("print d[13] is",d[13])
print("print d[14] is",d[14])
print("print d[15] is",d[15])
print("print d[16] is",d[16])
print("print d[17] is",d[17])
print("print d[18] is",d[18])
print("print d[19] is",d[19])
print("print d[20] is",d[20])
print("print d[21] is",d[21])
print("print d[22] is",d[22])
print("print d[1 :2] is",d[1:2])
print("print d[1 :4] is",d[1:4])
print("print d[1 :6] is",d[1:6])
# #Revesere Priniting
print(len(d) -1)

print(d[-23])
print(d[-22])
print(d[-21])
print(d[-20])
print(d[-19])
print(d[-18])
print(d[-17])
print(d[-16])
print(d[-15])
print(d[-14])
print(d[-13])
print(d[-12])
print(d[-11])
print(d[-10])
print(d[-9])
print(d[-8])
print(d[-7])
print(d[-6])
print(d[-5])
print(d[-4])
print(d[-3])
print(d[-2])
print(d[-1])

print("\n\n\n\n new line")

print(d[-1])
print(d[-2])
print(d[-3])
print(d[-4])
print(d[-5])
print(d[-6])
print(d[-7])
print(d[-8])
print(d[-9])
print(d[-10])
print(d[-11])
print(d[-12])
print(d[-13])
print(d[-14])
print(d[-15])
print(d[-16])
print(d[-17])
print(d[-18])
print(d[-19])
print(d[-20])
print(d[-21])
print(d[-22])
print(d[-23])


#positive indexing
print(d[0:1])
print(d[0:2])
print(d[0:3])
print(d[0:4])
print(d[0:5])
print(d[0:6])
print(d[0:7])
print(d[0:8])
print(d[0:9])
print(d[0:10])
print(d[0:11])
print(d[0:12])
print(d[0:13])
print(d[0:15])
print(d[0:16])
print(d[0:17])
print(d[0:18])
print(d[0:19])
print(d[0:20])
print(d[0:21])
print(d[0:22])
print(d[0:23])

print(d[:1])
print(d[:2])
print(d[:3])
print(d[:4])
print(d[:5])
print(d[:6])
print(d[:7])
print(d[:8])
print(d[:9])
print(d[:10])
print(d[:11])
print(d[:12])
print(d[:13])
print(d[:14])
print(d[:15])
print(d[:16])
print(d[:17])
print(d[:18])
print(d[:19])
print(d[:20])
print(d[:21])
print(d[:22])
print(d[:23])
print(d[1:])
print(d[2:])
print(d[3:])
print(d[4:])
print(d[5:])
print(d[6:])
print(d[7:])
print(d[8:])
print(d[9:])
print(d[10:])
print(d[11:])
print(d[12:])
print(d[13:])
print(d[14:])
print(d[15:])
print(d[16:])
print(d[17:])
print(d[18:])
print(d[19:])
print(d[20:])
print(d[21:])
print(d[22:])
print(d[23:])

print(d[0:0])
print(d[1:-1])
print(d[2:-2])
print(d[3:-3])
print(d[4:-4])
print(d[5:-5])
print(d[6:-6])
print(d[7:-7])
print(d[8:-8])
print(d[9:-9])
print(d[10:-10])
# Out:
# Aerospace - Engineering
# <class 'str'>
# 23
# print d[0] is A
# print d[1] is e
# print d[2] is r
# print d[3] is o
# print d[4] is s
# print d[5] is p
# print d[6] is a
# print d[7] is c
# print d[8] is e
# print d[10] is -
# print d[12] is E
# print d[13] is n
# print d[14] is g
# print d[15] is i
# print d[16] is n
# print d[17] is e
# print d[18] is e
# print d[19] is r
# print d[20] is i
# print d[21] is n
# print d[22] is g
# print d[1 :2] is e
# print d[1 :4] is ero
# print d[1 :6] is erosp
# 22
# A
# e
# r
# o
# s
# p
# a
# c
# e
#
# -
#
# E
# n
# g
# i
# n
# e
# e
# r
# i
# n
# g
#
#
#
#
#  new line
# g
# n
# i
# r
# e
# e
# n
# i
# g
# n
# E
#
# -
#
# e
# c
# a
# p
# s
# o
# r
# e
# A
# A
# Ae
# Aer
# Aero
# Aeros
# Aerosp
# Aerospa
# Aerospac
# Aerospace
# Aerospace
# Aerospace -
# Aerospace -
# Aerospace - E
# Aerospace - Eng
# Aerospace - Engi
# Aerospace - Engin
# Aerospace - Engine
# Aerospace - Enginee
# Aerospace - Engineer
# Aerospace - Engineeri
# ...
