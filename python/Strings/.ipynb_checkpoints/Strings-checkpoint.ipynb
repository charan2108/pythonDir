# %%
a = 'Hello World'
print(a[0])
print(a[1])
print(a[2])
print(a[3])
print(a[4])
print(a[5])
print(a[6])
print(a[7])
print(a[8])
print(a[9])
print(a[10])

print(a[0:0])
print(a[0:1])
print(a[0:2])
print(a[0:3])
print(a[0:4])
print(a[0:5])
print(a[0:6])
print(a[0:7])
print(a[0:8])
print(a[0:9])
print(a[0:10])

print(a[:0])
print(a[:1])
print(a[:2])
print(a[:3])
print(a[:4])
print(a[:5])
print(a[:6])
print(a[:7])
print(a[:8])
print(a[:9])
print(a[:10])

print(a[:0])
print(a[:-1])
print(a[:-2])
print(a[:-3])
print(a[:-4])
print(a[:-5])
print(a[:-7])
print(a[:-8])
print(a[:-9])
print(a[:-10])
print(a)
print(type(a))
print(id(a))

#String sequence operations
print(a.find('ello'))
#Replace 
print(a.replace('ello', 'ELLO'))
print(a.replace('orld', 'ORLD'))
#Count
print(a.count('1', 0, 4))
print(max(a))
print(min(a))
print(a.isalpha())
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d
#
# H
# He
# Hel
# Hell
# Hello
# Hello
# Hello W
# Hello Wo
# Hello Wor
# Hello Worl
#
# H
# He
# Hel
# Hell
# Hello
# Hello
# Hello W
# Hello Wo
# Hello Wor
# Hello Worl
#
# Hello Worl
# Hello Wor
# Hello Wo
# Hello W
# Hello
# Hell
# Hel
# He
# H
# Hello World
# <class 'str'>
# 1994893181616
# 1
# HELLO World
# Hello WORLD
# 0
# r
#
# False

# %%
#String sequence operations
print(a.find('ello'))
# Out:
# 1

# %%
#split count upper max min isalpha
y = 'W, e, l,c ,o, m, e'
print(y)
print(type(y))
print(y.split(','))
print(y.count('1', 0, 4))
print(y.upper())
print(max(y))
print(min(y))
print(y.isalpha())
# Out:
# W, e, l,c ,o, m, e
# <class 'str'>
# ['W', ' e', ' l', 'c ', 'o', ' m', ' e']
# 0
# W, E, L,C ,O, M, E
# o
#
# False

# %%
str = 'Welcome to F1 Race'
print(str)
print(str[0])
print(str[0:1])
print(str[0:2])
print(str[0:3])
print(str[0:4])
print(str[0:5])
print(str[0:6])
print(str[0:7])
print(str[0:8])
print(str[0:9])
print(str[0:10])
print(str[0:11])
print(str[0:12])
print(str[0:13])
print(str[0:14])
print(str[0:15])
print(str[0:16])
print(str[0:17])
print(str[0:18])
print(str[2:15])
print(str[2:10])
print(str[:5])
print(str[:15])
print(str * 2)
print(str +  "test \t")
print(type(str))
# Out:
# Welcome to F1 Race
# W
# W
# We
# Wel
# Welc
# Welco
# Welcom
# Welcome
# Welcome
# Welcome t
# Welcome to
# Welcome to
# Welcome to F
# Welcome to F1
# Welcome to F1
# Welcome to F1 R
# Welcome to F1 Ra
# Welcome to F1 Rac
# Welcome to F1 Race
# lcome to F1 R
# lcome to
# Welco
# Welcome to F1 R
# Welcome to F1 RaceWelcome to F1 Race
# Welcome to F1 Racetest
